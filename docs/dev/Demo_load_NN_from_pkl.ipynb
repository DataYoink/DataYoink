# %%
from pyfiles_for_demos.img_rescale import img_rescale
from pyfiles_for_demos.predict import predict_discharge_curve
from pyfiles_for_demos.predict import show_output_img_and_mask
# Out:
# ** fvcore version of PathManager will be deprecated soon. **
# ** Please migrate to the version in iopath repo. **
# https://github.com/facebookresearch/iopath
#
# ** fvcore version of PathManager will be deprecated soon. **
# ** Please migrate to the version in iopath repo. **
# https://github.com/facebookresearch/iopath

# %% [markdown]
# ### 1. Rescale input image for prediction

# %%
image_PNG = "Test_bw.png"

image_height = 400
image_width = 600
rescaled_img = img_rescale(image_PNG, image_height, image_width)
# Out:
# original image shape: (1493, 2583) is scaled to new image shape (400, 600)

# %% [markdown]
# ### 2. Make discharge curve prediction with pretrained CNN from .pkl file

# %%
pretrained_pkl = "./output/BEST_config.pkl"
outputs = predict_discharge_curve(pretrained_pkl,rescaled_img)

# %% [markdown]
# ### 3. Visulize predicted masks

# %%
show_output_img_and_mask("scaled_input_image/scaled_"+image_PNG, outputs)

# %%
image_PNG = "discharge_curve (9).png"
rescaled_img = img_rescale(image_PNG, image_height, image_width)
pretrained_pkl = "./output/BEST_config.pkl"
outputs = predict_discharge_curve(pretrained_pkl,rescaled_img)
show_output_img_and_mask("scaled_input_image/scaled_"+image_PNG, outputs)
# Out:
# original image shape: (400, 600) is scaled to new image shape (400, 600)

# %%
image_PNG = "discharge_curve (3).png"
rescaled_img = img_rescale(image_PNG, image_height, image_width)
pretrained_pkl = "./output/BEST_config.pkl"
outputs = predict_discharge_curve(pretrained_pkl,rescaled_img)
show_output_img_and_mask("scaled_input_image/scaled_"+image_PNG, outputs)
# Out:
# original image shape: (400, 600) is scaled to new image shape (400, 600)

# %%
image_PNG = "discharge_curve (15).png"
rescaled_img = img_rescale(image_PNG, image_height, image_width)
pretrained_pkl = "./output/BEST_config.pkl"
outputs = predict_discharge_curve(pretrained_pkl,rescaled_img)
show_output_img_and_mask("scaled_input_image/scaled_"+image_PNG, outputs)
# Out:
# original image shape: (400, 600) is scaled to new image shape (400, 600)

# %%
image_PNG = "discharge_curve (20).png"
rescaled_img = img_rescale(image_PNG, image_height, image_width)
pretrained_pkl = "./output/BEST_config.pkl"
outputs = predict_discharge_curve(pretrained_pkl,rescaled_img)
show_output_img_and_mask("scaled_input_image/scaled_"+image_PNG, outputs)
# Out:
# original image shape: (400, 600) is scaled to new image shape (400, 600)

# %%
image_PNG = "discharge_curve (25).png"
rescaled_img = img_rescale(image_PNG, image_height, image_width)
pretrained_pkl = "./output/BEST_config.pkl"
outputs = predict_discharge_curve(pretrained_pkl,rescaled_img)
show_output_img_and_mask("scaled_input_image/scaled_"+image_PNG, outputs)
# Out:
# original image shape: (400, 600) is scaled to new image shape (400, 600)
# No instance predicted, showing only the image

# %%
image_PNG = "discharge_curve (29).png"
rescaled_img = img_rescale(image_PNG, image_height, image_width)
pretrained_pkl = "./output/BEST_config.pkl"
outputs = predict_discharge_curve(pretrained_pkl,rescaled_img)
show_output_img_and_mask("scaled_input_image/scaled_"+image_PNG, outputs)
# Out:
# original image shape: (400, 600) is scaled to new image shape (400, 600)

# %%
image_PNG = "discharge_curve (33).png"
rescaled_img = img_rescale(image_PNG, image_height, image_width)
pretrained_pkl = "./output/BEST_config.pkl"
outputs = predict_discharge_curve(pretrained_pkl,rescaled_img)
show_output_img_and_mask("scaled_input_image/scaled_"+image_PNG, outputs)
# Out:
# original image shape: (400, 600) is scaled to new image shape (400, 600)
